# %% [markdown]
# **Assignment-9: K-Means Clustering**
#
# Objective: Apply K-Means clustering on a dataset, understand cluster formation, and visualize results.

# %% [markdown]
# **# Step 1: Import required libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

# %% [markdown]
# **# Step 2: Create dataset**

# %%
data = {
    'Income': [15,18,20,22,25,30,35,40,45,50,55,60,65,70,75,80],
    'Score':  [39,81,6,77,40,76,6,94,3,72,14,60,19,85,25,90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Income  Score
# 0       15     39
# 1       18     81
# 2       20      6
# 3       22     77
# 4       25     40
# 5       30     76
# 6       35      6
# 7       40     94
# 8       45      3
# 9       50     72
# 10      55     14
# 11      60     60
# 12      65     19
# 13      70     85
# 14      75     25
# 15      80     90

# %% [markdown]
# **# Step 3: Select features**

# %%
X = df[['Income', 'Score']]

# %% [markdown]
# **# Step 4: Apply K-Means with 3 clusters**

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %% [markdown]
# **# Step 5: Get cluster labels**

# %%
df['Cluster'] = kmeans.labels_

print(df)
# Out:
#     Income  Score  Cluster
# 0       15     39        2
# 1       18     81        0
# 2       20      6        2
# 3       22     77        0
# 4       25     40        2
# 5       30     76        0
# 6       35      6        1
# 7       40     94        0
# 8       45      3        1
# 9       50     72        0
# 10      55     14        1
# 11      60     60        0
# 12      65     19        1
# 13      70     85        0
# 14      75     25        1
# 15      80     90        0

# %% [markdown]
# **# Step 6: Get centroids**

# %%
centroids = kmeans.cluster_centers_

print("Centroids:")
print(centroids)
# Out:
# Centroids:
# [[46.25       79.375     ]
#  [55.         13.4       ]
#  [20.         28.33333333]]

# %% [markdown]
# **# Step 7: Visualize clusters**

# %%
plt.scatter(df['Income'], df['Score'], c=df['Cluster'], cmap='viridis', s=100)
plt.scatter(centroids[:,0], centroids[:,1], color='red', marker='X', s=200, label='Centroids')

plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("K-Means Clustering")
plt.legend()
plt.show()

# %% [markdown]
# **# Step 8: Elbow Method (Optional)**

# %%
inertia = []

for k in range(1, 6):
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(X)
    inertia.append(model.inertia_)

plt.plot(range(1, 6), inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()
